# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# Read the dataset from CSV file
df = pd.read_csv('iris.data', names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'target'])

# %%
# Extract the features (assuming one feature 'x') and target variable 'y'
x = df['sepal_length'].values
y = df['petal_length'].values

# %%
# Calculate the means of x and y
mean_x = np.mean(x)
mean_y = np.mean(y)

# %%
# Total number of values
n = len(x)

# %%
# Using the formula to calculate b1 and b0
numer = 0
denom = 0
for i in range(n):
    numer += (x[i] - mean_x) * (y[i] - mean_y)
    denom += (x[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)

# %%
# Print coefficients
print("Coefficients:")
print("b0:", b0)
print("b1:", b1)
# Out:
# Coefficients:
# b0: -7.09538147827932
# b1: 1.8575096654214465

# %%
# Making predictions
predictions = b0 + b1 * x

# %%
# Calculate metrics
mse = np.mean((predictions - y) ** 2)
mae = np.mean(np.abs(predictions - y))
rss = np.sum((predictions - y) ** 2)
tss = np.sum((y - mean_y) ** 2)
r_squared = 1 - (rss / tss)

# %%
# Print metrics
print("\nMetrics:")
print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("R-squared (R2):", r_squared)
# Out:
# Metrics:
# Mean Squared Error (MSE): 0.7423201713947026
# Mean Absolute Error (MAE): 0.7060119824037672
# R-squared (R2): 0.7599553107783261

# %%
# Plotting the regression line
plt.scatter(x, y, color='blue', label='Original data')  # Original data
plt.plot(x, predictions, color='red', label='Regression line')  # Regression line
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.title('Linear Regression')
plt.legend()
plt.show()
